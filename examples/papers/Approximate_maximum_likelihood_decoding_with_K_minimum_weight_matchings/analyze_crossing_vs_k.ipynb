# %% [markdown]
# # Analysis of Fidelity Crossing Points as a Function of K
#
# This notebook analyzes how the σ value at which fidelity crosses a threshold changes as a function of K (number of minimum weight matchings) for different distance values.

# %%
using JLD2
using Plots
# using Interpolations
using Statistics

# %% [markdown]
# ## Load and Examine Data

# %%
# Load the data
data_file = "data/surface_square_mwms_5_15_0.596_0.607_400_3_1023680.jld2"
data = load(data_file)

# Display the keys to understand the structure
println("Keys in the data file:")
for key in keys(data)
    println("  $key: ", typeof(data[key]))
end
# Out:
# Keys in the data file:
#   num_samples: Int64
#   σrange: StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}
#   p_list: Dict{Any, Any}
#   t_list: Dict{Any, Any}
#   drange: StepRange{Int64, Int64}

# %%
# Extract the main data dictionary (assuming it's the largest object)
data_dict = nothing
for (key, value) in data
    if isa(value, Dict) && length(value) > 10  # Heuristic to find the main data
        data_dict = value
        println("Found main data dictionary with key: $key")
        break
    end
end

if data_dict === nothing
    # If heuristic fails, let's examine all dictionaries
    println("Examining all dictionary objects:")
    for (key, value) in data
        if isa(value, Dict)
            println("  $key: Dict with $(length(value)) entries")
            if length(value) > 0
                first_key = first(keys(value))
                println("    Sample key: $first_key, value type: $(typeof(value[first_key]))")
            end
        end
    end
end
# Out:
# Found main data dictionary with key: p_list

# %%
# If the above doesn't work, let's manually select the data
# Uncomment and modify the line below if needed:
# data_dict = data["your_key_here"]

println("Data loaded successfully!")
println("Number of [σ, d] combinations: ", length(data_dict))

# Extract all unique σ and d values
all_keys = collect(keys(data_dict))
sigma_values = unique([key[1] for key in all_keys])
d_values = unique([key[2] for key in all_keys])

sort!(sigma_values)
sort!(d_values)

println("σ range: ", minimum(sigma_values), " to ", maximum(sigma_values))
println("d values: ", d_values)

# Determine K from the length of the first data vector
first_key = first(all_keys)
K_max = length(data_dict[first_key])
println("Maximum K: ", K_max)
println("Sample data point: ", data_dict[first_key][1:min(5, K_max)])
# Out:
# Data loaded successfully!
# Number of [σ, d] combinations: 72
# σ range: 0.596 to 0.607
# d values: [5.0, 7.0, 9.0, 11.0, 13.0, 15.0]
# Maximum K: 401
# Sample data point: Any[0.841741559862457, 0.8419994529540481, 0.8440196155048453, 0.8445686151922476, 0.8450834245076586]

# %% [markdown]
# ## Define Functions for Finding Crossing Points

# %%
"""
    find_crossing_sigma(sigma_values, fidelity_values, threshold=0.5)

Find the σ value where fidelity crosses a given threshold using linear interpolation.

# Arguments
- `sigma_values`: Array of σ values
- `fidelity_values`: Array of corresponding fidelity values
- `threshold`: Crossing threshold (default: 0.5)

# Returns
- The σ value at crossing, or NaN if no crossing is found
"""
function find_crossing_sigma(sigma_values, fidelity_values, threshold=0.5)
    # Remove any NaN or missing values
    valid_indices = .!isnan.(fidelity_values) .& .!ismissing.(fidelity_values)
    sigma_clean = sigma_values[valid_indices]
    fidelity_clean = fidelity_values[valid_indices]
    
    if length(sigma_clean) < 2
        return NaN
    end
    
    # Sort by sigma values
    sort_indices = sortperm(sigma_clean)
    sigma_sorted = sigma_clean[sort_indices]
    fidelity_sorted = fidelity_clean[sort_indices]
    
    # Find crossing points
    for i in 1:(length(fidelity_sorted)-1)
        f1, f2 = fidelity_sorted[i], fidelity_sorted[i+1]
        s1, s2 = sigma_sorted[i], sigma_sorted[i+1]
        
        # Check if threshold is crossed between these two points
        if (f1 <= threshold <= f2) || (f2 <= threshold <= f1)
            # Linear interpolation to find exact crossing point
            if f2 != f1  # Avoid division by zero
                crossing_sigma = s1 + (threshold - f1) * (s2 - s1) / (f2 - f1)
                return crossing_sigma
            end
        end
    end
    
    return NaN  # No crossing found
end
# Out:
# find_crossing_sigma

# %% [markdown]
# ## Analyze Crossing Points for d=13 and d=15

# %%
function analyze_crossings_for_distance(data_dict, d, threshold=0.5)
    """
    Analyze crossing points for a specific distance d.
    """
    # Extract all keys for this distance
    all_keys = collect(keys(data_dict))
    relevant_keys = [key for key in all_keys if key[2] == d]
    
    if isempty(relevant_keys)
        println("Warning: No data found for d=$d")
        return Dict()
    end
    
    sort!(relevant_keys, by=x->x[1])  # Sort by σ
    sigmas_for_d = [key[1] for key in relevant_keys]
    
    # Determine K_max from first data point
    K_max = length(data_dict[relevant_keys[1]])
    
    crossing_sigmas = Float64[]
    k_values = Int[]
    
    println("\nAnalyzing d=$d ($(length(relevant_keys)) σ values, K_max=$K_max)...")
    
    for k in 1:K_max
        # Extract fidelity values for this K across all σ values
        fidelities = [data_dict[key][k] for key in relevant_keys]
        
        # Find crossing point
        crossing_sigma = find_crossing_sigma(sigmas_for_d, fidelities, threshold)
        
        if !isnan(crossing_sigma)
            push!(crossing_sigmas, crossing_sigma)
            push!(k_values, k)
            println("  K=$k: crossing at σ=$(round(crossing_sigma, digits=4))")
        else
            println("  K=$k: no crossing found")
        end
    end
    
    return Dict(
        "k_values" => k_values,
        "crossing_sigmas" => crossing_sigmas,
        "sigma_range" => sigmas_for_d,
        "d" => d
    )
end

# Analyze for both distances
target_distances = [13, 15]
threshold = 0.5

results = Dict()
for d in target_distances
    results[d] = analyze_crossings_for_distance(data_dict, d, threshold)
end
# Out:
# Analyzing d=13 (12 σ values, K_max=401)...
#   K=1: no crossing found
#   K=2: no crossing found
#   K=3: no crossing found
#   K=4: no crossing found
#   K=5: no crossing found
#   K=6: no crossing found
#   K=7: no crossing found
#   K=8: no crossing found
#   K=9: no crossing found
#   K=10: no crossing found
#   K=11: no crossing found
#   K=12: no crossing found
#   K=13: no crossing found
#   K=14: no crossing found
#   K=15: no crossing found
#   K=16: no crossing found
#   K=17: no crossing found
#   K=18: no crossing found
#   K=19: no crossing found
#   K=20: no crossing found
#   K=21: no crossing found
#   K=22: no crossing found
#   K=23: no crossing found
#   K=24: no crossing found
#   K=25: no crossing found
#   K=26: no crossing found
#   K=27: no crossing found
#   K=28: no crossing found
#   K=29: no crossing found
#   K=30: no crossing found
#   K=31: no crossing found
#   K=32: no crossing found
#   K=33: no crossing found
#   K=34: no crossing found
#   K=35: no crossing found
#   K=36: no crossing found
#   K=37: no crossing found
#   K=38: no crossing found
#   K=39: no crossing found
#   K=40: no crossing found
#   K=41: no crossing found
#   K=42: no crossing found
#   K=43: no crossing found
#   K=44: no crossing found
#   K=45: no crossing found
#   K=46: no crossing found
#   K=47: no crossing found
#   K=48: no crossing found
#   K=49: no crossing found
#   K=50: no crossing found
#   K=51: no crossing found
#   K=52: no crossing found
#   K=53: no crossing found
#   K=54: no crossing found
#   K=55: no crossing found
#   K=56: no crossing found
#   K=57: no crossing found
#   K=58: no crossing found
#   K=59: no crossing found
#   K=60: no crossing found
#   K=61: no crossing found
#   K=62: no crossing found
#   K=63: no crossing found
#   K=64: no crossing found
#   K=65: no crossing found
#   K=66: no crossing found
#   K=67: no crossing found
#   K=68: no crossing found
#   K=69: no crossing found
#   K=70: no crossing found
#   K=71: no crossing found
#   K=72: no crossing found
#   K=73: no crossing found
#   K=74: no crossing found
#   K=75: no crossing found
#   K=76: no crossing found
#   K=77: no crossing found
#   K=78: no crossing found
#   K=79: no crossing found
#   K=80: no crossing found
#   K=81: no crossing found
#   K=82: no crossing found
#   K=83: no crossing found
#   K=84: no crossing found
#   K=85: no crossing found
#   K=86: no crossing found
#   K=87: no crossing found
#   K=88: no crossing found
#   K=89: no crossing found
#   K=90: no crossing found
#   K=91: no crossing found
#   K=92: no crossing found
#   K=93: no crossing found
#   K=94: no crossing found
#   K=95: no crossing found
#   K=96: no crossing found
#   K=97: no crossing found
#   K=98: no crossing found
#   K=99: no crossing found
#   K=100: no crossing found
#   K=101: no crossing found
#   K=102: no crossing found
#   K=103: no crossing found
#   K=104: no crossing found
#   K=105: no crossing found
#   K=106: no crossing found
#   K=107: no crossing found
#   K=108: no crossing found
#   K=109: no crossing found
#   K=110: no crossing found
#   K=111: no crossing found
#   K=112: no crossing found
#   K=113: no crossing found
#   K=114: no crossing found
#   K=115: no crossing found
#   K=116: no crossing found
#   K=117: no crossing found
#   K=118: no crossing found
#   K=119: no crossing found
#   K=120: no crossing found
#   K=121: no crossing found
#   K=122: no crossing found
#   K=123: no crossing found
#   K=124: no crossing found
#   K=125: no crossing found
#   K=126: no crossing found
#   K=127: no crossing found
#   K=128: no crossing found
#   K=129: no crossing found
#   K=130: no crossing found
#   K=131: no crossing found
#   K=132: no crossing found
#   K=133: no crossing found
#   K=134: no crossing found
#   K=135: no crossing found
#   K=136: no crossing found
#   K=137: no crossing found
#   K=138: no crossing found
#   K=139: no crossing found
#   K=140: no crossing found
#   K=141: no crossing found
#   K=142: no crossing found
#   K=143: no crossing found
#   K=144: no crossing found
#   K=145: no crossing found
#   K=146: no crossing found
#   K=147: no crossing found
#   K=148: no crossing found
#   K=149: no crossing found
#   K=150: no crossing found
#   K=151: no crossing found
#   K=152: no crossing found
#   K=153: no crossing found
#   K=154: no crossing found
#   K=155: no crossing found
#   K=156: no crossing found
#   K=157: no crossing found
#   K=158: no crossing found
#   K=159: no crossing found
#   K=160: no crossing found
#   K=161: no crossing found
#   K=162: no crossing found
#   K=163: no crossing found
#   K=164: no crossing found
#   K=165: no crossing found
#   K=166: no crossing found
#   K=167: no crossing found
#   K=168: no crossing found
#   K=169: no crossing found
#   K=170: no crossing found
#   K=171: no crossing found
#   K=172: no crossing found
#   K=173: no crossing found
#   K=174: no crossing found
#   K=175: no crossing found
#   K=176: no crossing found
#   K=177: no crossing found
#   K=178: no crossing found
#   K=179: no crossing found
#   K=180: no crossing found
#   K=181: no crossing found
#   K=182: no crossing found
#   K=183: no crossing found
#   K=184: no crossing found
#   K=185: no crossing found
#   K=186: no crossing found
#   K=187: no crossing found
#   K=188: no crossing found
#   K=189: no crossing found
#   K=190: no crossing found
#   K=191: no crossing found
#   K=192: no crossing found
#   K=193: no crossing found
#   K=194: no crossing found
#   K=195: no crossing found
#   K=196: no crossing found
#   K=197: no crossing found
#   K=198: no crossing found
#   K=199: no crossing found
#   K=200: no crossing found
#   K=201: no crossing found
#   K=202: no crossing found
#   K=203: no crossing found
#   K=204: no crossing found
#   K=205: no crossing found
#   K=206: no crossing found
#   K=207: no crossing found
#   K=208: no crossing found
#   K=209: no crossing found
#   K=210: no crossing found
#   K=211: no crossing found
#   K=212: no crossing found
#   K=213: no crossing found
#   K=214: no crossing found
#   K=215: no crossing found
#   K=216: no crossing found
#   K=217: no crossing found
#   K=218: no crossing found
#   K=219: no crossing found
#   K=220: no crossing found
#   K=221: no crossing found
#   K=222: no crossing found
#   K=223: no crossing found
#   K=224: no crossing found
#   K=225: no crossing found
#   K=226: no crossing found
#   K=227: no crossing found
#   K=228: no crossing found
#   K=229: no crossing found
#   K=230: no crossing found
#   K=231: no crossing found
#   K=232: no crossing found
#   K=233: no crossing found
#   K=234: no crossing found
#   K=235: no crossing found
#   K=236: no crossing found
#   K=237: no crossing found
#   K=238: no crossing found
#   K=239: no crossing found
#   K=240: no crossing found
#   K=241: no crossing found
#   K=242: no crossing found
#   K=243: no crossing found
#   K=244: no crossing found
#   K=245: no crossing found
#   K=246: no crossing found
#   K=247: no crossing found
#   K=248: no crossing found
#   K=249: no crossing found
#   K=250: no crossing found
#   K=251: no crossing found
#   K=252: no crossing found
#   K=253: no crossing found
#   K=254: no crossing found
#   K=255: no crossing found
#   K=256: no crossing found
#   K=257: no crossing found
#   K=258: no crossing found
#   K=259: no crossing found
#   K=260: no crossing found
#   K=261: no crossing found
#   K=262: no crossing found
#   K=263: no crossing found
#   K=264: no crossing found
#   K=265: no crossing found
#   K=266: no crossing found
#   K=267: no crossing found
#   K=268: no crossing found
#   K=269: no crossing found
#   K=270: no crossing found
#   K=271: no crossing found
#   K=272: no crossing found
#   K=273: no crossing found
#   K=274: no crossing found
#   K=275: no crossing found
#   K=276: no crossing found
#   K=277: no crossing found
#   K=278: no crossing found
#   K=279: no crossing found
#   K=280: no crossing found
#   K=281: no crossing found
#   K=282: no crossing found
#   K=283: no crossing found
#   K=284: no crossing found
#   K=285: no crossing found
#   K=286: no crossing found
#   K=287: no crossing found
#   K=288: no crossing found
#   K=289: no crossing found
#   K=290: no crossing found
#   K=291: no crossing found
#   K=292: no crossing found
#   K=293: no crossing found
#   K=294: no crossing found
#   K=295: no crossing found
#   K=296: no crossing found
#   K=297: no crossing found
#   K=298: no crossing found
#   K=299: no crossing found
#   K=300: no crossing found
#   K=301: no crossing found
#   K=302: no crossing found
#   K=303: no crossing found
#   K=304: no crossing found
#   K=305: no crossing found
#   K=306: no crossing found
#   K=307: no crossing found
#   K=308: no crossing found
#   K=309: no crossing found
#   K=310: no crossing found
#   K=311: no crossing found
#   K=312: no crossing found
#   K=313: no crossing found
#   K=314: no crossing found
#   K=315: no crossing found
#   K=316: no crossing found
#   K=317: no crossing found
#   K=318: no crossing found
#   K=319: no crossing found
#   K=320: no crossing found
#   K=321: no crossing found
#   K=322: no crossing found
#   K=323: no crossing found
#   K=324: no crossing found
#   K=325: no crossing found
#   K=326: no crossing found
#   K=327: no crossing found
#   K=328: no crossing found
#   K=329: no crossing found
#   K=330: no crossing found
#   K=331: no crossing found
#   K=332: no crossing found
#   K=333: no crossing found
#   K=334: no crossing found
#   K=335: no crossing found
#   K=336: no crossing found
#   K=337: no crossing found
#   K=338: no crossing found
#   K=339: no crossing found
#   K=340: no crossing found
#   K=341: no crossing found
#   K=342: no crossing found
#   K=343: no crossing found
#   K=344: no crossing found
#   K=345: no crossing found
#   K=346: no crossing found
#   K=347: no crossing found
#   K=348: no crossing found
#   K=349: no crossing found
#   K=350: no crossing found
#   K=351: no crossing found
#   K=352: no crossing found
#   K=353: no crossing found
#   K=354: no crossing found
#   K=355: no crossing found
#   K=356: no crossing found
#   K=357: no crossing found
#   K=358: no crossing found
#   K=359: no crossing found
#   K=360: no crossing found
#   K=361: no crossing found
#   K=362: no crossing found
#   K=363: no crossing found
#   K=364: no crossing found
#   K=365: no crossing found
#   K=366: no crossing found
#   K=367: no crossing found
#   K=368: no crossing found
#   K=369: no crossing found
#   K=370: no crossing found
#   K=371: no crossing found
#   K=372: no crossing found
#   K=373: no crossing found
#   K=374: no crossing found
#   K=375: no crossing found
#   K=376: no crossing found
#   K=377: no crossing found
#   K=378: no crossing found
#   K=379: no crossing found
#   K=380: no crossing found
#   K=381: no crossing found
#   K=382: no crossing found
#   K=383: no crossing found
#   K=384: no crossing found
#   K=385: no crossing found
#   K=386: no crossing found
#   K=387: no crossing found
#   K=388: no crossing found
#   K=389: no crossing found
#   K=390: no crossing found
#   K=391: no crossing found
#   K=392: no crossing found
#   K=393: no crossing found
#   K=394: no crossing found
#   K=395: no crossing found
#   K=396: no crossing found
#   K=397: no crossing found
#   K=398: no crossing found
#   K=399: no crossing found
#   K=400: no crossing found
#   K=401: no crossing found
#
# Analyzing d=15 (12 σ values, K_max=401)...
#   K=1: no crossing found
#   K=2: no crossing found
#   K=3: no crossing found
#   K=4: no crossing found
#   K=5: no crossing found
#   K=6: no crossing found
#   K=7: no crossing found
#   K=8: no crossing found
#   K=9: no crossing found
#   K=10: no crossing found
#   K=11: no crossing found
#   K=12: no crossing found
#   K=13: no crossing found
#   K=14: no crossing found
#   K=15: no crossing found
#   K=16: no crossing found
#   K=17: no crossing found
#   K=18: no crossing found
#   K=19: no crossing found
#   K=20: no crossing found
#   K=21: no crossing found
#   K=22: no crossing found
#   K=23: no crossing found
#   K=24: no crossing found
#   K=25: no crossing found
#   K=26: no crossing found
#   K=27: no crossing found
#   K=28: no crossing found
#   K=29: no crossing found
#   K=30: no crossing found
#   K=31: no crossing found
#   K=32: no crossing found
#   K=33: no crossing found
#   K=34: no crossing found
#   K=35: no crossing found
#   K=36: no crossing found
#   K=37: no crossing found
#   K=38: no crossing found
#   K=39: no crossing found
#   K=40: no crossing found
#   K=41: no crossing found
#   K=42: no crossing found
#   K=43: no crossing found
#   K=44: no crossing found
#   K=45: no crossing found
#   K=46: no crossing found
#   K=47: no crossing found
#   K=48: no crossing found
#   K=49: no crossing found
#   K=50: no crossing found
#   K=51: no crossing found
#   K=52: no crossing found
#   K=53: no crossing found
#   K=54: no crossing found
#   K=55: no crossing found
#   K=56: no crossing found
#   K=57: no crossing found
#   K=58: no crossing found
#   K=59: no crossing found
#   K=60: no crossing found
#   K=61: no crossing found
#   K=62: no crossing found
#   K=63: no crossing found
#   K=64: no crossing found
#   K=65: no crossing found
#   K=66: no crossing found
#   K=67: no crossing found
#   K=68: no crossing found
#   K=69: no crossing found
#   K=70: no crossing found
#   K=71: no crossing found
#   K=72: no crossing found
#   K=73: no crossing found
#   K=74: no crossing found
#   K=75: no crossing found
#   K=76: no crossing found
#   K=77: no crossing found
#   K=78: no crossing found
#   K=79: no crossing found
#   K=80: no crossing found
#   K=81: no crossing found
#   K=82: no crossing found
#   K=83: no crossing found
#   K=84: no crossing found
#   K=85: no crossing found
#   K=86: no crossing found
#   K=87: no crossing found
#   K=88: no crossing found
#   K=89: no crossing found
#   K=90: no crossing found
#   K=91: no crossing found
#   K=92: no crossing found
#   K=93: no crossing found
#   K=94: no crossing found
#   K=95: no crossing found
#   K=96: no crossing found
#   K=97: no crossing found
#   K=98: no crossing found
#   K=99: no crossing found
#   K=100: no crossing found
#   K=101: no crossing found
#   K=102: no crossing found
#   K=103: no crossing found
#   K=104: no crossing found
#   K=105: no crossing found
#   K=106: no crossing found
#   K=107: no crossing found
#   K=108: no crossing found
#   K=109: no crossing found
#   K=110: no crossing found
#   K=111: no crossing found
#   K=112: no crossing found
#   K=113: no crossing found
#   K=114: no crossing found
#   K=115: no crossing found
#   K=116: no crossing found
#   K=117: no crossing found
#   K=118: no crossing found
#   K=119: no crossing found
#   K=120: no crossing found
#   K=121: no crossing found
#   K=122: no crossing found
#   K=123: no crossing found
#   K=124: no crossing found
#   K=125: no crossing found
#   K=126: no crossing found
#   K=127: no crossing found
#   K=128: no crossing found
#   K=129: no crossing found
#   K=130: no crossing found
#   K=131: no crossing found
#   K=132: no crossing found
#   K=133: no crossing found
#   K=134: no crossing found
#   K=135: no crossing found
#   K=136: no crossing found
#   K=137: no crossing found
#   K=138: no crossing found
#   K=139: no crossing found
#   K=140: no crossing found
#   K=141: no crossing found
#   K=142: no crossing found
#   K=143: no crossing found
#   K=144: no crossing found
#   K=145: no crossing found
#   K=146: no crossing found
#   K=147: no crossing found
#   K=148: no crossing found
#   K=149: no crossing found
#   K=150: no crossing found
#   K=151: no crossing found
#   K=152: no crossing found
#   K=153: no crossing found
#   K=154: no crossing found
#   K=155: no crossing found
#   K=156: no crossing found
#   K=157: no crossing found
#   K=158: no crossing found
#   K=159: no crossing found
#   K=160: no crossing found
#   K=161: no crossing found
#   K=162: no crossing found
#   K=163: no crossing found
#   K=164: no crossing found
#   K=165: no crossing found
#   K=166: no crossing found
#   K=167: no crossing found
#   K=168: no crossing found
#   K=169: no crossing found
#   K=170: no crossing found
#   K=171: no crossing found
#   K=172: no crossing found
#   K=173: no crossing found
#   K=174: no crossing found
#   K=175: no crossing found
#   K=176: no crossing found
#   K=177: no crossing found
#   K=178: no crossing found
#   K=179: no crossing found
#   K=180: no crossing found
#   K=181: no crossing found
#   K=182: no crossing found
#   K=183: no crossing found
#   K=184: no crossing found
#   K=185: no crossing found
#   K=186: no crossing found
#   K=187: no crossing found
#   K=188: no crossing found
#   K=189: no crossing found
#   K=190: no crossing found
#   K=191: no crossing found
#   K=192: no crossing found
#   K=193: no crossing found
#   K=194: no crossing found
#   K=195: no crossing found
#   K=196: no crossing found
#   K=197: no crossing found
#   K=198: no crossing found
#   K=199: no crossing found
#   K=200: no crossing found
#   K=201: no crossing found
#   K=202: no crossing found
#   K=203: no crossing found
#   K=204: no crossing found
#   K=205: no crossing found
#   K=206: no crossing found
#   K=207: no crossing found
#   K=208: no crossing found
#   K=209: no crossing found
#   K=210: no crossing found
#   K=211: no crossing found
#   K=212: no crossing found
#   K=213: no crossing found
#   K=214: no crossing found
#   K=215: no crossing found
#   K=216: no crossing found
#   K=217: no crossing found
#   K=218: no crossing found
#   K=219: no crossing found
#   K=220: no crossing found
#   K=221: no crossing found
#   K=222: no crossing found
#   K=223: no crossing found
#   K=224: no crossing found
#   K=225: no crossing found
#   K=226: no crossing found
#   K=227: no crossing found
#   K=228: no crossing found
#   K=229: no crossing found
#   K=230: no crossing found
#   K=231: no crossing found
#   K=232: no crossing found
#   K=233: no crossing found
#   K=234: no crossing found
#   K=235: no crossing found
#   K=236: no crossing found
#   K=237: no crossing found
#   K=238: no crossing found
#   K=239: no crossing found
#   K=240: no crossing found
#   K=241: no crossing found
#   K=242: no crossing found
#   K=243: no crossing found
#   K=244: no crossing found
#   K=245: no crossing found
#   K=246: no crossing found
#   K=247: no crossing found
#   K=248: no crossing found
#   K=249: no crossing found
#   K=250: no crossing found
#   K=251: no crossing found
#   K=252: no crossing found
#   K=253: no crossing found
#   K=254: no crossing found
#   K=255: no crossing found
#   K=256: no crossing found
#   K=257: no crossing found
#   K=258: no crossing found
#   K=259: no crossing found
#   K=260: no crossing found
#   K=261: no crossing found
#   K=262: no crossing found
#   K=263: no crossing found
#   K=264: no crossing found
#   K=265: no crossing found
#   K=266: no crossing found
#   K=267: no crossing found
#   K=268: no crossing found
#   K=269: no crossing found
#   K=270: no crossing found
#   K=271: no crossing found
#   K=272: no crossing found
#   K=273: no crossing found
#   K=274: no crossing found
#   K=275: no crossing found
#   K=276: no crossing found
#   K=277: no crossing found
#   K=278: no crossing found
#   K=279: no crossing found
#   K=280: no crossing found
#   K=281: no crossing found
#   K=282: no crossing found
#   K=283: no crossing found
#   K=284: no crossing found
#   K=285: no crossing found
#   K=286: no crossing found
#   K=287: no crossing found
#   K=288: no crossing found
#   K=289: no crossing found
#   K=290: no crossing found
#   K=291: no crossing found
#   K=292: no crossing found
#   K=293: no crossing found
#   K=294: no crossing found
#   K=295: no crossing found
#   K=296: no crossing found
#   K=297: no crossing found
#   K=298: no crossing found
#   K=299: no crossing found
#   K=300: no crossing found
#   K=301: no crossing found
#   K=302: no crossing found
#   K=303: no crossing found
#   K=304: no crossing found
#   K=305: no crossing found
#   K=306: no crossing found
#   K=307: no crossing found
#   K=308: no crossing found
#   K=309: no crossing found
#   K=310: no crossing found
#   K=311: no crossing found
#   K=312: no crossing found
#   K=313: no crossing found
#   K=314: no crossing found
#   K=315: no crossing found
#   K=316: no crossing found
#   K=317: no crossing found
#   K=318: no crossing found
#   K=319: no crossing found
#   K=320: no crossing found
#   K=321: no crossing found
#   K=322: no crossing found
#   K=323: no crossing found
#   K=324: no crossing found
#   K=325: no crossing found
#   K=326: no crossing found
#   K=327: no crossing found
#   K=328: no crossing found
#   K=329: no crossing found
#   K=330: no crossing found
#   K=331: no crossing found
#   K=332: no crossing found
#   K=333: no crossing found
#   K=334: no crossing found
#   K=335: no crossing found
#   K=336: no crossing found
#   K=337: no crossing found
#   K=338: no crossing found
#   K=339: no crossing found
#   K=340: no crossing found
#   K=341: no crossing found
#   K=342: no crossing found
#   K=343: no crossing found
#   K=344: no crossing found
#   K=345: no crossing found
#   K=346: no crossing found
#   K=347: no crossing found
#   K=348: no crossing found
#   K=349: no crossing found
#   K=350: no crossing found
#   K=351: no crossing found
#   K=352: no crossing found
#   K=353: no crossing found
#   K=354: no crossing found
#   K=355: no crossing found
#   K=356: no crossing found
#   K=357: no crossing found
#   K=358: no crossing found
#   K=359: no crossing found
#   K=360: no crossing found
#   K=361: no crossing found
#   K=362: no crossing found
#   K=363: no crossing found
#   K=364: no crossing found
#   K=365: no crossing found
#   K=366: no crossing found
#   K=367: no crossing found
#   K=368: no crossing found
#   K=369: no crossing found
#   K=370: no crossing found
#   K=371: no crossing found
#   K=372: no crossing found
#   K=373: no crossing found
#   K=374: no crossing found
#   K=375: no crossing found
#   K=376: no crossing found
#   K=377: no crossing found
#   K=378: no crossing found
#   K=379: no crossing found
#   K=380: no crossing found
#   K=381: no crossing found
#   K=382: no crossing found
#   K=383: no crossing found
#   K=384: no crossing found
#   K=385: no crossing found
#   K=386: no crossing found
#   K=387: no crossing found
#   K=388: no crossing found
#   K=389: no crossing found
#   K=390: no crossing found
#   K=391: no crossing found
#   K=392: no crossing found
#   K=393: no crossing found
#   K=394: no crossing found
#   K=395: no crossing found
#   K=396: no crossing found
#   K=397: no crossing found
#   K=398: no crossing found
#   K=399: no crossing found
#   K=400: no crossing found
#   K=401: no crossing found

# %% [markdown]
# ## Visualize Results

# %%
# Plot crossing σ values as a function of K
p = plot(xlabel="K (number of minimum weight matchings)", 
         ylabel="Crossing σ value", 
         title="Fidelity Crossing Points vs K (threshold = $threshold)",
         legend=:topright,
         size=(800, 600))

colors = [:blue, :red, :green, :orange, :purple]
markers = [:circle, :square, :diamond, :triangle, :star]

for (i, d) in enumerate(target_distances)
    if haskey(results, d) && !isempty(results[d]["k_values"])
        plot!(p, results[d]["k_values"], results[d]["crossing_sigmas"], 
              marker=markers[i], linewidth=2, markersize=6,
              color=colors[i], label="d=$d")
    end
end

display(p)

# %% [markdown]
# ## Detailed Analysis and Summary

# %%
println("=== DETAILED SUMMARY ===")
println("Threshold used: $threshold")
println()

for d in target_distances
    if haskey(results, d) && !isempty(results[d]["k_values"])
        println("Distance d=$d:")
        k_vals = results[d]["k_values"]
        crossing_vals = results[d]["crossing_sigmas"]
        
        println("  Number of K values with crossings: $(length(k_vals))")
        println("  K range: $(minimum(k_vals)) to $(maximum(k_vals))")
        println("  σ_crossing range: $(round(minimum(crossing_vals), digits=4)) to $(round(maximum(crossing_vals), digits=4))")
        
        if length(crossing_vals) > 1
            # Calculate trend
            trend = crossing_vals[end] - crossing_vals[1]
            trend_per_k = trend / (k_vals[end] - k_vals[1])
            println("  Overall trend: σ_crossing changes by $(round(trend, digits=4)) from K=$(k_vals[1]) to K=$(k_vals[end])")
            println("  Average change per K: $(round(trend_per_k, digits=6))")
            
            # Calculate correlation
            if length(k_vals) > 2
                correlation = cor(k_vals, crossing_vals)
                println("  Correlation between K and σ_crossing: $(round(correlation, digits=4))")
            end
        end
        
        println("  Detailed values:")
        for (k, sigma) in zip(k_vals, crossing_vals)
            println("    K=$k: σ_crossing = $(round(sigma, digits=6))")
        end
        println()
    else
        println("Distance d=$d: No crossings found")
        println()
    end
end

# %% [markdown]
# ## Optional: Visualize Fidelity Curves for Selected K Values

# %%
# Plot fidelity curves for a few K values to visualize the crossing behavior
function plot_fidelity_curves(data_dict, d, k_values_to_plot=[1, 5, 10], threshold=0.5)
    all_keys = collect(keys(data_dict))
    relevant_keys = [key for key in all_keys if key[2] == d]
    sort!(relevant_keys, by=x->x[1])
    
    sigmas = [key[1] for key in relevant_keys]
    
    p = plot(xlabel="σ", ylabel="Fidelity", 
             title="Fidelity vs σ for d=$d (selected K values)",
             legend=:topright, size=(800, 600))
    
    # Add threshold line
    hline!([threshold], color=:black, linestyle=:dash, linewidth=2, label="Threshold = $threshold")
    
    colors = [:blue, :red, :green, :orange, :purple, :brown, :pink]
    
    for (i, k) in enumerate(k_values_to_plot)
        if k <= length(data_dict[relevant_keys[1]])
            fidelities = [data_dict[key][k] for key in relevant_keys]
            plot!(p, sigmas, fidelities, 
                  marker=:circle, linewidth=2, markersize=3,
                  color=colors[i], label="K=$k")
        end
    end
    
    return p
end

# Plot for both distances
for d in target_distances
    if haskey(results, d) && !isempty(results[d]["k_values"])
        # Select a few representative K values
        k_vals = results[d]["k_values"]
        k_to_plot = [k_vals[1], k_vals[div(length(k_vals), 2)], k_vals[end]]
        k_to_plot = unique(k_to_plot)  # Remove duplicates
        
        p = plot_fidelity_curves(data_dict, d, k_to_plot, threshold)
        display(p)
    end
end

# %% [markdown]
# ## Save Results

# %%
# Save the crossing analysis results
output_file = "crossing_analysis_results.jld2"
save(output_file, "results", results, "threshold", threshold, "target_distances", target_distances)
println("Results saved to $output_file")

# Also save as a simple text summary
open("crossing_analysis_summary.txt", "w") do io
    println(io, "Fidelity Crossing Analysis Summary")
    println(io, "Threshold: $threshold")
    println(io, "Target distances: $target_distances")
    println(io, "")
    
    for d in target_distances
        if haskey(results, d) && !isempty(results[d]["k_values"])
            println(io, "Distance d=$d:")
            k_vals = results[d]["k_values"]
            crossing_vals = results[d]["crossing_sigmas"]
            
            for (k, sigma) in zip(k_vals, crossing_vals)
                println(io, "  K=$k: σ_crossing = $sigma")
            end
            println(io, "")
        end
    end
end

println("Summary saved to crossing_analysis_summary.txt")
