# %%
using LatticeAlgorithms

# %% [markdown]
# # [[72, 12, 6]]

# %%
l, m, d = 6, 6, 6
A_terms = [(:x, 3), (:y, 1), (:y, 2)]
B_terms = [(:y, 3), (:x, 1), (:x, 2)]

HX, HZ = bb_check_matrices(l, m, A_terms, B_terms)
t = @elapsed dZ = css_distance(HX, HZ; sector=:Z)
println([dZ == d, t])
# dX = css_distance(HX, HZ; sector=:X)
# @assert dX == d
# Out:
# [1.0, 0.658583916]

# %% [markdown]
# # [[90, 8, 10]]

# %%
l, m, d = 15, 3, 10
A_terms = [(:x, 9), (:y, 1), (:y, 2)]
B_terms = [(:I, 0), (:x, 2), (:x, 7)]

HX, HZ = bb_check_matrices(l, m, A_terms, B_terms)
t = @elapsed dZ = css_distance(HX, HZ; sector=:Z)
println([dZ == d, t])
# dX = css_distance(HX, HZ; sector=:X)
# @assert dX == d
# Out:
# [1.0, 1459.060746208]

# %% [markdown]
# # [[108, 8, 10]]

# %%
l, m, d = 9, 6, 10
A_terms = [(:x, 3), (:y, 1), (:y, 2)]
B_terms = [(:y, 3), (:x, 1), (:x, 2)]

HX, HZ = bb_check_matrices(l, m, A_terms, B_terms)
t = @elapsed dZ = css_distance(HX, HZ; sector=:Z)
println([dZ == d, t])
# dX = css_distance(HX, HZ; sector=:X)
# @assert dX == d
# Out:
# [1.0, 6563.521497416]

# %% [markdown]
# # [[144, 12, 12]]

# %%
l, m, d = 12, 6, 12
A_terms = [(:x, 3), (:y, 1), (:y, 2)]
B_terms = [(:y, 3), (:x, 1), (:x, 2)]

HX, HZ = bb_check_matrices(l, m, A_terms, B_terms)
t = @elapsed dZ = css_distance(HX, HZ; sector=:Z)
println([dZ == d, t])
# dX = css_distance(HX, HZ; sector=:X)
# @assert dX == d

## stop after 2000 minutes.
# Out:
# InterruptException:
#
# Stacktrace:
#  [1] copy
#    @ ./array.jl:369 [inlined]
#  [2] (::LatticeAlgorithms.var"#in_rowspace_rref#279")(v::Vector{Int64}, R::Matrix{Int64}, pivots::Vector{Int64})
#    @ LatticeAlgorithms ~/Documents/Research/LatticeAlgorithms.jl_github/LatticeAlgorithms.jl/src/css_ldpc_utils.jl:381
#  [3] (::LatticeAlgorithms.var"#recurse#284"{Vector{Int64}, Vector{Int64}, Base.RefValue{Int64}, Vector{Int64}, Matrix{Int64}, Int64, Matrix{Int64}, LatticeAlgorithms.var"#toggle_row!#281", LatticeAlgorithms.var"#in_rowspace_rref#279"})(start_idx::Int64, num_left::Int64)
#    @ LatticeAlgorithms ~/Documents/Research/LatticeAlgorithms.jl_github/LatticeAlgorithms.jl/src/css_ldpc_utils.jl:421
# ...

# %% [markdown]
# # [[288, 12, 18]]

# %%
l, m, d = 12, 12, 18
A_terms = [(:x, 3), (:y, 2), (:y, 7)]
B_terms = [(:y, 3), (:x, 1), (:x, 2)]

HX, HZ = bb_check_matrices(l, m, A_terms, B_terms)
t = @elapsed dZ = css_distance(HX, HZ; sector=:Z)
println([dZ == d, t])
# dX = css_distance(HX, HZ; sector=:X)
# @assert dX == d
