# %%
using LatticeAlgorithms
n = 10 # Dimension of the lattice
M = rand(n, n) # A lattice Λ generated by a random matrix
x = rand(n) # A random input vector
y = closest_point(x, M) # The closest lattice point in \Lambda to x
# Out:
# 10-element Vector{Float64}:
#   0.9766225572198672
#   0.5288539076311779
#   0.11838048479172175
#   1.1820437744562218
#   0.26340193686874397
#   0.9938119370458113
#  -0.052711055867430696
#   0.22883351302845065
#   0.25567827064228454
#   0.5814078140791659
